# %% [markdown]
# <a href="https://colab.research.google.com/github/ioshubham/SparkGCollab/blob/main/SarkInstallation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run below commands to download the spark from apache website
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://apache.osuosl.org/spark/spark-3.4.2/spark-3.4.2-bin-hadoop3.tgz
# !tar xf spark-3.4.2-bin-hadoop3.tgz
# !pip install -q findspark

# %%
# !ls -a
# Out:
# .  ..  .config	sample_data  spark-3.4.2-bin-hadoop3  spark-3.4.2-bin-hadoop3.tgz

# %%
# Run below command to setup environment for  the spark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.2-bin-hadoop3"

# %%
#initialising Spark
import findspark
findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").getOrCreate()
# Test the spark
df = spark.createDataFrame([{"hello": "world"} for x in range(1000)])

df.show(3, False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a3c7e00ae820> in <cell line: 3>()
#       1 #initialising Spark
#       2 import findspark
# ----> 3 findspark.init()
#       4
#       5 from pyspark.sql import SparkSession
#
# /usr/local/lib/python3.10/dist-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     141
#     142     if not spark_home:
# --> 143         spark_home = find()
#     144
#     145     if not python_path:
#
# /usr/local/lib/python3.10/dist-packages/findspark.py in find()
#      44
#      45     if not spark_home:
# ---> 46         raise ValueError(
#      47             "Couldn't find Spark, make sure SPARK_HOME env is set"
#      48             " or Spark is in an expected location (e.g. from homebrew installation)."
#
# ...

# %%
# Check the pyspark version
import pyspark
print(pyspark.__version__)
# Out:
# 3.4.2

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
import cv2
import numpy as np
from google.colab import drive

# %%
spark = SparkSession.builder \
    .appName("VideoToFrames") \
    .getOrCreate()

# %%
def extract_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    success, image = cap.read()
    while success:
        frames.append(image)
        success, image = cap.read()

    return frames

# %%
video_path = r"/f/SparkIP.mp4"

if not os.path.isfile(video_path):
    raise ValueError("Invalid video path")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-6bfbabfd64f7> in <cell line: 3>()
#       2
#       3 if not os.path.isfile(video_path):
# ----> 4     raise ValueError("Invalid video path")
#
# ValueError: Invalid video path

# %%
frames_rdd = spark.sparkContext.parallelize(extract_frames(video_path))

first_frame = frames_rdd.first()
cv2.imshow('First Frame', first_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

spark.stop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1a804111305d> in <cell line: 3>()
#       1 frames_rdd = spark.sparkContext.parallelize(extract_frames(video_path))
#       2
# ----> 3 first_frame = frames_rdd.first()
#       4 cv2.imshow('First Frame', first_frame)
#       5 cv2.waitKey(0)
#
# /content/spark-3.4.2-bin-hadoop3/python/pyspark/rdd.py in first(self)
#    2870         if rs:
#    2871             return rs[0]
# -> 2872         raise ValueError("RDD is empty")
#    2873
#    2874     def isEmpty(self) -> bool:
#
# ValueError: RDD is empty

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
import cv2
import numpy as np
from google.colab import drive

from google.colab import files

uploaded = files.upload()
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")
# Out:
#      <input type="file" id="files-9bf41db2-558e-4d39-949d-ead6ec465fed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bf41db2-558e-4d39-949d-ead6ec465fed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np

# Function to read video file and print all frames
def print_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video file.")
        return

    frame_count = 0
    while True:
        success, frame = cap.read()
        if not success:
            break

        print(f"Frame {frame_count}: {frame}")
        frame_count += 1

    cap.release()

# Path to the video file (update this with the filename you uploaded)
video_path = list(uploaded.keys())[0]

# Call the function to print all frames
print_frames(video_path)
# Out:
# Streaming output truncated to the last 5000 lines.
#   [ 22  22 102]
#   [ 22  22 102]]]
# Frame 3064: [[[ 19  17  89]
#   [ 19  17  89]
#   [ 19  17  89]
#   ...
#   [231 234 255]
#   [249 252 255]
#   [243 246 255]]
#
#  [[ 19  17  89]
#   [ 19  17  89]
#   [ 19  17  89]
#   ...
#   [234 237 255]
#   [246 249 255]
#   [239 242 253]]
#
#  [[ 18  16  88]
#   [ 18  16  88]
#   [ 18  16  88]
#   ...
#   [232 238 255]
#   [237 244 255]
#   [238 245 255]]
#
#  ...
#
#  [[ 10  11  97]
#   [ 10  11  97]
#   [ 10  11  97]
#   ...
#   [ 23  22 100]
#   [ 21  21 101]
#   [ 21  21 101]]
#
#  [[ 10  11  97]
#   [ 10  11  97]
#   [ 10  11  97]
#   ...
#   [ 23  22 100]
#   [ 21  21 101]
#   [ 21  21 101]]
#
#  [[ 10  11  97]
#   [ 10  11  97]
#   [ 10  11  97]
#   ...
#   [ 24  23 101]
#   [ 22  22 102]
#   [ 22  22 102]]]
# Frame 3065: [[[ 19  17  89]
#   [ 19  17  89]
#   [ 19  17  89]
#   ...
#   [231 234 255]
#   [249 252 255]
#   [243 246 255]]
#
#  [[ 19  17  89]
#   [ 19  17  89]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

#!pip install sparkmagic

from pyspark.sql import SparkSession
import cv2
import numpy as np
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 13.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.1/221.1 kB 27.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
# ...

# %%
spark = SparkSession.builder \
    .appName("VideoToFrames") \
    .getOrCreate()

# %%
video_path = '/content/drive/MyDrive/SparkIP.mp4'

# %%
import cv2

# Function to read video file and extract frames
def extract_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    success, image = cap.read()
    while success:
        frames.append(image)
        success, image = cap.read()
    return frames

# Path to the video file
video_path = '/content/drive/MyDrive/SparkIP.mp4'

# Extract frames from video
frames = extract_frames(video_path)

# Print the number of frames extracted
print(f"Number of frames extracted: {len(frames)}")

# %%
from google.colab import drive
drive.mount('/content/drive')
from pyspark.sql import SparkSession
import cv2
import numpy as np
spark = SparkSession.builder \
    .appName("VideoToFrames") \
    .getOrCreate()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4f77c3b8b4ed> in <cell line: 3>()
#       1 from google.colab import drive
#       2 drive.mount('/content/drive')
# ----> 3 from pyspark.sql import SparkSession
#       4 import cv2
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pyspark'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Env Setup

#!apt-get install openjdk-8-jdk-headless -qq > /dev/null
#!wget -q http://apache.osuosl.org/spark/spark-3.4.2/spark-3.4.2-bin-hadoop3.tgz
#!tar xf spark-3.4.2-bin-hadoop3.tgz
#!pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.2-bin-hadoop3"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import findspark
findspark.init()
from pyspark.sql import SparkSession
import cv2
import numpy as np
spark = SparkSession.builder \
    .appName("VideoToFrames") \
    .getOrCreate()
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p "/content/drive/My Drive/videoSnaps"

def FrameCapture(path):
    vidObj = cv2.VideoCapture(path)
    count = 0
    success = 1
    while success:
        success, image = vidObj.read()
        cv2.imwrite("/content/drive/My Drive/videoSnaps/frame%d.jpg" % count, image)
        count += 1

if __name__ == '__main__':
    video_path = '/content/drive/MyDrive/SparkIP.mp4'
    FrameCapture(video_path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-396877de826a> in <cell line: 12>()
#      12 if __name__ == '__main__':
#      13     video_path = '/content/drive/MyDrive/SparkIP.mp4'
# ---> 14     FrameCapture(video_path)
#
# <ipython-input-7-396877de826a> in FrameCapture(path)
#       7     while success:
#       8         success, image = vidObj.read()
# ----> 9         cv2.imwrite("/content/drive/My Drive/videoSnaps/frame%d.jpg" % count, image)
#      10         count += 1
#      11
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:787: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
# !mkdir -p "/content/drive/My Drive/videoSnapsUsingFPS"

def FrameCapture(path):
    vidObj = cv2.VideoCapture(path)
    count = 0

    fps = vidObj.get(cv2.CAP_PROP_FPS)

    interval = int(fps)

    success = 1

    while success:
        success, image = vidObj.read()

        if count % interval == 0:
            if success:
                cv2.imwrite("/content/drive/My Drive/videoSnapsUsingFPS/frame%d.jpg" % count, image)
            else:
                print("End of video reached")
        count += 1

if __name__ == '__main__':
    video_path = '/content/drive/MyDrive/SparkIP.mp4'
    FrameCapture(video_path)

# %%
#Use this snippet to test

# !mkdir -p "/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicate"


def FrameCapture(path):
    vidObj = cv2.VideoCapture(path)

    count = 0

    fps = vidObj.get(cv2.CAP_PROP_FPS)

    interval = int(fps)

    time_to_capture = fps

    captured_frames = []

    success = 1

    while success:
        success, image = vidObj.read()

        if count >= time_to_capture:
            if count not in captured_frames:
                if success:
                    cv2.imwrite("/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicate/frame%d.jpg" % count, image)
                else:
                    print("End of video reached")
                captured_frames.append(count)
            time_to_capture += fps
        count += 1

if __name__ == '__main__':
    video_path = '/content/drive/MyDrive/SparkIP.mp4'
    FrameCapture(video_path)

# %%
# !mkdir -p "/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp"
def frames_are_similar(frame1, frame2):
    # Convert frames to grayscale
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Compute the structural similarity index
    ssim = cv2.compare_ssim(gray_frame1, gray_frame2)

    # If SSIM is high, frames are similar (likely duplicates)
    return ssim > 0.95  # Adjust this threshold as needed

def FrameCapture(path):


    vidObj = cv2.VideoCapture(path)

    count = 0

    fps = vidObj.get(cv2.CAP_PROP_FPS)

    interval = int(fps)

    time_to_capture = fps

    success, prev_frame = vidObj.read()

    while success:

        success, current_frame = vidObj.read()

        if count >= time_to_capture:
            if success:
                if not frames_are_similar(prev_frame, current_frame):
                    cv2.imwrite("/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp/frame%d.jpg" % count, current_frame)
                    print("Frame %d saved to Google Drive" % count)

                    prev_frame = current_frame
                else:
                    print("Duplicate frame %d skipped" % count)
            else:
                print("End of video reached")
            time_to_capture += fps

        count += 1

if __name__ == '__main__':
    video_path = '/content/drive/MyDrive/SparkIP.mp4'
    FrameCapture(video_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-45fafa1722c5> in <cell line: 47>()
#      47 if __name__ == '__main__':
#      48     video_path = '/content/drive/MyDrive/SparkIP.mp4'
# ---> 49     FrameCapture(video_path)
#
# <ipython-input-12-45fafa1722c5> in FrameCapture(path)
#      32         if count >= time_to_capture:
#      33             if success:
# ---> 34                 if not frames_are_similar(prev_frame, current_frame):
#      35                     cv2.imwrite("/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp/frame%d.jpg" % count, current_frame)
#      36                     print("Frame %d saved to Google Drive" % count)
#
# <ipython-input-12-45fafa1722c5> in frames_are_similar(frame1, frame2)
#       6
#       7     # Compute the structural similarity index
# ----> 8     ssim = cv2.compare_ssim(gray_frame1, gray_frame2)
# ...

# %%
# !mkdir -p "/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp"
def frames_are_similar(frame1, frame2):
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Compute Mean Squared Error (MSE)
    mse = np.mean((gray_frame1 - gray_frame2) ** 2)

    # If MSE is low, frames are similar (likely duplicates)
    return mse < 1000  # Adjust this threshold as needed

def FrameCapture(path):


    vidObj = cv2.VideoCapture(path)

    count = 0

    fps = vidObj.get(cv2.CAP_PROP_FPS)

    interval = int(fps)

    time_to_capture = 1000

    success, prev_frame = vidObj.read()

    while success:

        success, current_frame = vidObj.read()

        if count >= time_to_capture:
            if success:
                if not frames_are_similar(prev_frame, current_frame):
                    cv2.imwrite("/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp/frame%d.jpg" % count, current_frame)

                    prev_frame = current_frame
            else:
                print("End of video reached")
            time_to_capture += 1000

        count += 1

if __name__ == '__main__':
    video_path = '/content/drive/MyDrive/SparkIP.mp4'
    FrameCapture(video_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f2936edfd0d8> in <cell line: 43>()
#      43 if __name__ == '__main__':
#      44     video_path = '/content/drive/MyDrive/SparkIP.mp4'
# ---> 45     FrameCapture(video_path)
#
# <ipython-input-9-f2936edfd0d8> in FrameCapture(path)
#      27     while success:
#      28
# ---> 29         success, current_frame = vidObj.read()
#      30
#      31         if count >= time_to_capture:
#
# KeyboardInterrupt:

# %%
# !mkdir -p "/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp"
import cv2

def frames_are_similar(frame1, frame2):
    # Convert frames to grayscale
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Compute Mean Squared Error (MSE)
    mse = ((gray_frame1 - gray_frame2) ** 2).mean()

    # If MSE is low, frames are similar (likely duplicates)
    return mse < 1000  # Adjust this threshold as needed

def FrameCapture(path):
    vidObj = cv2.VideoCapture(path)

    count = 0

    success, prev_frame = vidObj.read()

    while success:
        success, current_frame = vidObj.read()

        if success:
            if not frames_are_similar(prev_frame, current_frame):
                cv2.imwrite(f"/content/drive/My Drive/videoSnapsUsingFPSRemoveDuplicateHelp/frame{count}.jpg", current_frame)

                prev_frame = current_frame

                count += 1

# Driver Code
if __name__ == '__main__':
    # Specify the path to your video file
    video_path = '/content/drive/MyDrive/SparkIP.mp4'

    # Calling the function to extract frames and save to Google Drive
    FrameCapture(video_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-1a0f3976b09b> in <cell line: 34>()
#      37
#      38     # Calling the function to extract frames and save to Google Drive
# ---> 39     FrameCapture(video_path)
#
# <ipython-input-20-1a0f3976b09b> in FrameCapture(path)
#      21
#      22     while success:
# ---> 23         success, current_frame = vidObj.read()
#      24
#      25         if success:
#
# KeyboardInterrupt:

# %%
import cv2
import os
import time

video_path = '/content/drive/MyDrive/SparkIP.mp4'
output_dir = '/content/drive/MyDrive/videoSnapsUsingFPSRemoveDuplicateHelp'

try:
    # Create directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
except OSError:
    print('Error: Creating directory')

video = cv2.VideoCapture(video_path)

fps = int(video.get(cv2.CAP_PROP_FPS))
print('The FPS of the video is', fps)

time_start = time.time()
currentframe = 0
saved_frames = []

while True:
    ret, frame = video.read()

    if ret:
        # Check if the current frame is similar to any saved frame
        similar_to_saved = any(cv2.matchTemplate(frame, saved_frame, cv2.TM_CCOEFF_NORMED)[0][0] > 0.95 for saved_frame in saved_frames)

        if not similar_to_saved:

            frame_path = os.path.join(output_dir, f"frame{currentframe}.jpg")
            cv2.imwrite(frame_path, frame)
            saved_frames.append(frame)

        currentframe += 1
    else:
        break

time_end = time.time()
print('Total time taken:', time_end - time_start)
print('Total frames saved:', currentframe)

# Release all space and windows once done
video.release()
cv2.destroyAllWindows()
# Out:
# The FPS of the video is 29
# Total time taken: 5993.9710574150085
# Total frames saved: 3166

# %%
#!pip install pytesseract
#!apt-get install tesseract-ocr-eng

import os
import cv2
import pytesseract
from google.colab import drive

drive.mount('/content/drive')

frames_folder = '/content/drive/MyDrive/videoSnapsUsingFPSRemoveDuplicateHelp'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 35 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (8,111 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 121749 files and directories currently installed.)
# ...

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
ocr_config = r'--oem 3 --psm 6'

# %%
search_text = 'Oh what fun'

# %%
for filename in os.listdir(frames_folder):
    if filename.endswith('.jpg'):
        # Read frame
        frame_path = os.path.join(frames_folder, filename)
        frame = cv2.imread(frame_path)

        # Perform OCR
        text = pytesseract.image_to_string(frame, config=ocr_config)

        # Search for desired text
        if search_text in text:
            print(f'text found in frame: {filename}')
# Out:
# text found in frame: frame975.jpg
